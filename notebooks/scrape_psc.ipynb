# %%
import requests
from bs4 import BeautifulSoup

# %%
link = "http://sos.ri.gov/openmeetings/?page=view_entity&id=4679"

# %%
f = requests.get(link)

# %%
print (f.text)
# Out:
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#     <meta http-equiv="Content-Type" content="text/html; charset=ISO-8859-1" />
#     <meta name="title" content="State of Rhode Island: Office of the Secretary of State"/>
#     <meta name="description" content="SOS"/>
#     <meta name="originatorJurisdiction" content="State of Rhode Island and Providence Plantations"/>
#     <meta name="originatorDepartment" content="Office of the Secretary of State"/>
#     <meta name="originatorOffice" content="SOS"/>
#     <meta name="createDate" content="2006 10/23"/>
#     <meta name="timePeriodTextual" content="current"/>
#     <meta name="medium" content="Web site"/>
#     <meta name="govType" content="state"/>
#     <meta name="keywords" content="Rhode Island State secretary of state, voting ucc, meeting minutes, public information"/>
#     <meta name="subjects" content="Government; rhode island; Office of the Secretary of State"/>
# ...

# %%
soup = BeautifulSoup(f.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <head>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <meta content="State of Rhode Island: Office of the Secretary of State" name="title"/>
#  <meta content="SOS" name="description"/>
#  <meta content="State of Rhode Island and Providence Plantations" name="originatorJurisdiction"/>
#  <meta content="Office of the Secretary of State" name="originatorDepartment"/>
#  <meta content="SOS" name="originatorOffice"/>
#  <meta content="2006 10/23" name="createDate"/>
#  <meta content="current" name="timePeriodTextual"/>
#  <meta content="Web site" name="medium"/>
#  <meta content="state" name="govType"/>
#  <meta content="Rhode Island State secretary of state, voting ucc, meeting minutes, public information" name="keywords"/>
#  <meta content="Government; rhode island; Office of the Secretary of State" name="subjects"/>
#  <meta content="SOS" name="contactOrganization"/>
# ...

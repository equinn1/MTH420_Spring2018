# %% [markdown]
# # Pandas exercise - baseball database

# %% [markdown]
# ### import required packages

# %%
import re
import numpy as np
import scipy as sc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Read the baseball database master file into a dataframe

# %%
master = pd.read_csv("../../baseballdatabank-2017.1/core/Master.csv")

# %% [markdown]
# ### display the attributes and member functions of the dataframe class

# %%
dir(master)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
# ...

# %% [markdown]
# ### display the shape attribute of the master database

# %%
master.shape
# Out:
# (19105, 24)

# %% [markdown]
# ### display the column names

# %%
master.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID'],
#       dtype='object')

# %% [markdown]
# ### Using the groupby() function to summarize

# %%
master.groupby('birthYear').count()
# Out:
#            playerID  birthMonth  birthDay  birthCountry  birthState  \
# birthYear
# 1820.0            1           1         1             1           1
# 1824.0            1           1         1             1           1
# 1831.0            1           0         0             1           1
# 1832.0            2           2         2             2           2
# 1835.0            1           1         1             1           0
# 1836.0            1           1         1             1           1
# 1837.0            1           1         1             1           1
# 1838.0            3           3         3             3           3
# 1839.0            1           1         1             1           1
# 1840.0            7           7         6             7           7
# 1841.0            3           2         0             3           2
# 1842.0            6           6         4             6           5
# 1843.0            8           8         6             8           7
# ...

# %% [markdown]
# ### Show the line limit for displays

# %%
pd.get_option("display.max_rows")
# Out:
# 200

# %% [markdown]
# ### Let's raise the limit to 200

# %%
pd.set_option("display.max_rows",200)
pd.get_option("display.max_rows")
# Out:
# 200

# %% [markdown]
# ### Now redo the summary by birth year

# %%
master.groupby('birthYear').count()
# Out:
#            playerID  birthMonth  birthDay  birthCountry  birthState  \
# birthYear
# 1820.0            1           1         1             1           1
# 1824.0            1           1         1             1           1
# 1831.0            1           0         0             1           1
# 1832.0            2           2         2             2           2
# 1835.0            1           1         1             1           0
# 1836.0            1           1         1             1           1
# 1837.0            1           1         1             1           1
# 1838.0            3           3         3             3           3
# 1839.0            1           1         1             1           1
# 1840.0            7           7         6             7           7
# 1841.0            3           2         0             3           2
# 1842.0            6           6         4             6           5
# 1843.0            8           8         6             8           7
# ...

# %% [markdown]
# ### Limiting the columns
#
# Note that not all columns are displayed.  We can limit the number of columns to a list.

# %%
master[['birthYear','playerID']].groupby('birthYear').count()
# Out:
#            playerID
# birthYear
# 1820.0            1
# 1824.0            1
# 1831.0            1
# 1832.0            2
# 1835.0            1
# 1836.0            1
# 1837.0            1
# 1838.0            3
# 1839.0            1
# 1840.0            7
# 1841.0            3
# 1842.0            6
# 1843.0            8
# 1844.0           17
# 1845.0           18
# 1846.0           13
# 1847.0           28
# 1848.0           23
# 1849.0           30
# 1850.0           44
# 1851.0           32
# 1852.0           41
# 1853.0           41
# 1854.0           53
# 1855.0           65
# 1856.0           73
# 1857.0           65
# 1858.0           91
# 1859.0           87
# 1860.0           87
# 1861.0           87
# 1862.0           91
# 1863.0          101
# 1864.0           94
# 1865.0          104
# 1866.0           97
# 1867.0          100
# 1868.0           90
# 1869.0          104
# 1870.0           81
# 1871.0           64
# 1872.0           71
# 1873.0           86
# ...

# %%
hall = pd.read_csv("../../baseballdatabank-2017.1/core/HallOfFame.csv")

# %%
hall.shape
# Out:
# (4156, 9)

# %%
hall.columns
# Out:
# Index(['playerID', 'yearid', 'votedBy', 'ballots', 'needed', 'votes',
#        'inducted', 'category', 'needed_note'],
#       dtype='object')

# %%
hall.head()
# Out:
#     playerID  yearid votedBy  ballots  needed  votes inducted category  \
# 0   cobbty01    1936   BBWAA    226.0   170.0  222.0        Y   Player
# 1   ruthba01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 2  wagneho01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 3  mathech01    1936   BBWAA    226.0   170.0  205.0        Y   Player
# 4  johnswa01    1936   BBWAA    226.0   170.0  189.0        Y   Player
#
#   needed_note
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
hall2 = hall.merge(master,how='inner',on='playerID')
hall2.shape
# Out:
# (4155, 32)

# %%
type(hall2)
# Out:
# pandas.core.frame.DataFrame

# %%
hall2.columns
# Out:
# Index(['playerID', 'yearid', 'votedBy', 'ballots', 'needed', 'votes',
#        'inducted', 'category', 'needed_note', 'birthYear', 'birthMonth',
#        'birthDay', 'birthCountry', 'birthState', 'birthCity', 'deathYear',
#        'deathMonth', 'deathDay', 'deathCountry', 'deathState', 'deathCity',
#        'nameFirst', 'nameLast', 'nameGiven', 'weight', 'height', 'bats',
#        'throws', 'debut', 'finalGame', 'retroID', 'bbrefID'],
#       dtype='object')

# %%
hall2[['nameFirst','nameLast','yearid','inducted']]
# Out:
#      nameFirst      nameLast  yearid inducted
# 0           Ty          Cobb    1936        Y
# 1         Babe          Ruth    1936        Y
# 2        Honus        Wagner    1936        Y
# 3        Honus        Wagner    1936        N
# 4      Christy     Mathewson    1936        Y
# 5       Walter       Johnson    1936        Y
# 6          Nap        Lajoie    1936        N
# 7          Nap        Lajoie    1936        N
# 8          Nap        Lajoie    1937        Y
# 9         Tris       Speaker    1936        N
# 10        Tris       Speaker    1937        Y
# 11          Cy         Young    1936        N
# 12          Cy         Young    1936        N
# 13          Cy         Young    1937        Y
# 14      Rogers       Hornsby    1936        N
# 15      Rogers       Hornsby    1937        N
# 16      Rogers       Hornsby    1938        N
# 17      Rogers       Hornsby    1939        N
# 18      Rogers       Hornsby    1942        Y
# ...
